# %%
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.6.0

# %%
im=cv2.imread('lena.jpg')

# %%
# offline version of opencv

cv2.imshow('image', im)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-10-0bcd29a2c225> in <module>
#       1 # offline version of opencv
#       2
# ----> 3 cv2.imshow('image', im)
#       4 cv2.waitKey(0)
#       5 cv2.destroyAllWindows()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
# colab opencv
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F5C6F06B650>

# %%
cv2.imwrite('lena_1.jpg',im)
# Out:
# True

# %%
cv2_imshow(im2)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F5666637C90>

# %% [markdown]
# color space RGB > red green blue
# BGR >  blue green red

# %%
im3=cv2.cvtColor(im,cv2.COLOR_BGR2HSV)

# %%
cv2_imshow(im3)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F5C6F03B6D0>

# %%
im.shape
# Out:
# (152, 160, 3)

# %%
import numpy as np

# %%
def translate (img,x,y):
  (h,w)=img.shape[:2]
  M=np.float32([[1,0,x],[0,1,y]])
  shifted=cv2.warpAffine(img,M,(w,h))
  return shifted

# %%
shifted=translate(im,10,50)

# %%
cv2_imshow(shifted)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F5C6EFEDA90>

# %%
def rotate (img, angle ,center=None, scale=1):
  (h,w)=img.shape[:2]
  if center is None:
    center=(w/2,h/2)
  M=cv2.getRotationMatrix2D(center,angle, scale)
  rotated=cv2.warpAffine(img,M,(w,h))
  return rotated

# %%
rotated=rotate(im,180)

# %%
cv2_imshow(rotated)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F5C6EF8B050>

# %%
im_flipp=cv2.flip(im,0)

# %%
cv2_imshow(im_flipp)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F5C6EFE9DD0>

# %%
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F565E558A10>

# %%
(h,w)=im.shape[:2]

# %%
im.shape
# Out:
# (152, 160, 3)

# %%
dst_size=(300,500)

# %%
dst_size1=(100,150)

# %%
method1=cv2.INTER_LINEAR

# %%
method2=cv2.INTER_NEAREST

# %%
zoomed=cv2.resize(im,dst_size,interpolation=method1)

# %%
cv2_imshow(zoomed)
# Out:
# <PIL.Image.Image image mode=RGB size=300x500 at 0x7F5C6EFEDAD0>

# %%
zoomed2=cv2.resize(im,dst_size,interpolation=method2)

# %%
cv2_imshow(zoomed2)
# Out:
# <PIL.Image.Image image mode=RGB size=300x500 at 0x7F5C6EFE9D90>

# %%
zoomed2=cv2.resize(im,dst_size,interpolation=method2)

# %%
cv2_imshow(zoomed3)
# Out:
# <PIL.Image.Image image mode=RGB size=100x150 at 0x7F565E5757D0>

# %%
cv2_imshow(zoomed2)
# Out:
# <PIL.Image.Image image mode=RGB size=300x500 at 0x7F565E566750>

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(im.ravel(),256,[0,256])
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
im1=cv2.imread('lena.jpg',0)

# %%
cv2_imshow(im1)
# Out:
# <PIL.Image.Image image mode=L size=160x152 at 0x7F5C6C52A6D0>

# %%
im_equal=cv2.equalizeHist(im1)

# %%
cv2_imshow(im_equal)
# Out:
# <PIL.Image.Image image mode=L size=160x152 at 0x7F5C6B7D6890>

# %%
plt.hist(im_equal.ravel(),256,[0,256])
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
blue=im[:,:,0]

# %%
green=im[:,:,1]

# %%
red=im[:,:,2]

# %%
cv2_imshow(blue)
# Out:
# <PIL.Image.Image image mode=L size=160x152 at 0x7F5C63706750>

# %%
cv2_imshow(green)
# Out:
# <PIL.Image.Image image mode=L size=160x152 at 0x7F5C63765E10>

# %%
cv2_imshow(red)
# Out:
# <PIL.Image.Image image mode=L size=160x152 at 0x7F5C64DEDB50>

# %%
red_equal=cv2.equalizeHist(red)
green_equal=cv2.equalizeHist(green)
blue_equal=cv2.equalizeHist(blue)

# %%
im_total=cv2.merge([blue_equal,green_equal,red_equal])

# %%
cv2_imshow(im_total)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F5C637505D0>

# %%
plt.hist(im_total.ravel(),256,[0,256])
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
cv2_imshow(im_equal)
# Out:
# <PIL.Image.Image image mode=L size=160x152 at 0x7F565B268790>

# %%
cv2_imshow(im1)
# Out:
# <PIL.Image.Image image mode=L size=160x152 at 0x7F565B268BD0>

# %%
im_median=cv2.medianBlur(im,5)

# %%
cv2_imshow(im_median)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F5C63018A90>

# %%
im_mean=cv2.blur(im,(3,3))

# %%
cv2_imshow(im_mean)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F565B2683D0>

# %%
mean_blur=np.ones([5,2],np.float32)/9
mean_blur
# Out:
# array([[0.11111111, 0.11111111],
#        [0.11111111, 0.11111111],
#        [0.11111111, 0.11111111],
#        [0.11111111, 0.11111111],
#        [0.11111111, 0.11111111]], dtype=float32)

# %%
im_filtered=cv2.filter2D(im,-1,mean_blur)

# %%
cv2_imshow(im_filtered)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F5C6306A5D0>

# %%
im_g=cv2.GaussianBlur(im,(5,5),0)

# %%
im_g2=cv2.GaussianBlur(im_g,(5,5),0)

# %%
cv2_imshow(im_g)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F5C6306ADD0>

# %%
cv2_imshow(im_g2)
# Out:
# <PIL.Image.Image image mode=RGB size=160x152 at 0x7F5C6307C750>
